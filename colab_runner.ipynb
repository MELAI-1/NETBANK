# %% [markdown]
# # Nedbank Transaction Volume Forecasting - Colab Runner
#
# This notebook allows you to run the optimized pipeline using Colab's resources.

# %%
# 1. Clone the repository
# !git clone https://github.com/MELAI-1/NETBANK.git
# %cd NETBANK

# 2. Install dependencies
# !pip install -r requirements.txt

# 3. Create data directory
# !mkdir -p data

# %% [markdown]
# ### ⚠️ Action Required: Upload your data
# Please upload your `.csv` and `.parquet` files to the `/content/NETBANK/data` folder using the Colab file explorer on the left.

# %%
# 4. Run the optimized pipeline
# !python main.py --data_path ./data --output_path submission_colab.csv
